# %%
import docx2txt
def extract_text_from_docx(doc_path):
    '''
    Helper function to extract plain text from .docx files

    :param doc_path: path to .docx file to be extracted
    :return: string of extracted text
    '''
    try:
        temp = docx2txt.process(doc_path)
        text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
        return '\n'.join(text)
    except KeyError:
        print('asfdashfh rewfaoiiafds')
        return ' '

# %%
#text = extract_text_from_docx("C:\\Nresume\\resume\\full_stack_dev\\Hemanthkumar_Resume.docx")
text = extract_text_from_docx("C:\\Nresume\\resume\\Hemanthkumar_Resume.docx")
print(text)
# Out:
# LANKE HEMANTH KUMAR
# Email: lankehemanth@gmail.com                                                                MobileNo:+91 9642290598
#
# Career Objective:
#    To pursue a challenging career in a software development industry where I can utilize my knowledge and skills positively for my personal development and for the growth of the organization while being innovative and flexible.
#
# Experience
# UCE-ATTENDANCE                                     January 2018 - Present
# Proposed and developed an Attendance Management System using Smart Phones and LAN. It uses Android application as the main interface for teachers and students and is based on OTP generation to register attendance. Project is developed using Java and MongoDB.
# STUDENTS CLUB  PORTAL:     July 2017 - September 2017
# ...

# %%
text_split = [i.strip() for i in text.split('\n')]

for phrase in text_split:
    print(phrase)
    print(len(phrase))
# Out:
# LANKE HEMANTH KUMAR
# 19
# Email: lankehemanth@gmail.com                                                                MobileNo:+91 9642290598
# 116
#
# 0
# Career Objective:
# 17
# To pursue a challenging career in a software development industry where I can utilize my knowledge and skills positively for my personal development and for the growth of the organization while being innovative and flexible.
# 224
#
# 0
# Experience
# 10
# UCE-ATTENDANCE                                     January 2018 - Present
# 73
# Proposed and developed an Attendance Management System using Smart Phones and LAN. It uses Android application as the main interface for teachers and students and is based on OTP generation to register attendance. Project is developed using Java and MongoDB.
# 258
# STUDENTS CLUB  PORTAL:     July 2017 - September 2017
# 53
# ...

# %%
from docx2pdf import convert

filename = "C:\\Nresume\\resume\\sample_se.docx"

if filename[-len('.docx'):]=='.docx':
    #convert(filename,filename[:-len('.docx')]+'.pdf')
    convert(filename)
